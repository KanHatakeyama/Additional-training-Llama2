# %%
#ライブラリの自動リロード
# %load_ext autoreload
# %autoreload 2
from scoring import generate_prompt,evaluate_answer,eval_model

# %%
import torch
from peft import PeftModel
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from transformers import pipeline

#load base model
model_id = "meta-llama/Llama-2-7b-chat-hf"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=bnb_config, 
                                             device_map="auto")
# Out:
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
pipe= pipeline("text-generation", model=model, tokenizer=tokenizer,max_new_tokens=100)

# %%
import json
dataset_path="../database/output/qa_dataset.json"
with open(dataset_path, "r") as f:
    raw_dataset = json.load(f)

# %%
#eval_model(raw_dataset[:50],pipe,"outputs/0929test/original_model.csv")

# %% [markdown]
# # peft

# %%
from peft import LoraConfig, get_peft_model

# %%
peft_config = LoraConfig(
        task_type="CAUSAL_LM", inference_mode=False, r=8, lora_alpha=32,
        lora_dropout=0.1
    )
model = get_peft_model(model, peft_config)

# %%
tokenizer.pad_token = tokenizer.eos_token

# %%
import transformers
from datasets import load_dataset

context_path="../database/output/context0926.json"
with open(context_path, 'r') as f:
    context_list = json.load(f)

context_list=context_list[:200]

with open("trainset/temp_train.txt","w") as f:
    for context in context_list:
        f.write(context+"\n")

train_dataset = load_dataset("text", data_files="trainset/temp_train.txt")
train_dataset=train_dataset.map(lambda samples: tokenizer(samples['text']), batched=True)
# Out:
# Downloading and preparing dataset text/default to /home/user/.cache/huggingface/datasets/text/default-7856b213db3cf53e/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset text downloaded and prepared to /home/user/.cache/huggingface/datasets/text/default-7856b213db3cf53e/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]

# %%
trainer = transformers.Trainer(
    model=model,
    train_dataset=train_dataset['train'],
    args=transformers.TrainingArguments(
        per_device_train_batch_size=1,
        gradient_accumulation_steps=4,
        warmup_steps=10,
        max_steps=len(train_dataset['train'])*1,
        learning_rate=2e-5,
        fp16=True,
        logging_steps=10,
        output_dir='outputs',
        #optim=""
    ),
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False)
)
model.config.use_cache = True  # silence the warnings. Please re-enable for inference!
trainer.train()
# Out:
# /home/user/miniconda3/envs/llama/lib/python3.11/site-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='200' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [200/200 08:18, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.759900</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.736200</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.593900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.574700</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>2.470800</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>2.497400</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>2.560300</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>2.534200</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>2.363900</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.466200</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>2.419100</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>2.473600</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>2.407300</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>2.460300</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>2.376200</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>2.331800</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>2.352800</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>2.451900</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>2.420500</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.420800</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=200, training_loss=2.483585948944092, metrics={'train_runtime': 502.1699, 'train_samples_per_second': 1.593, 'train_steps_per_second': 0.398, 'total_flos': 7754540595609600.0, 'train_loss': 2.483585948944092, 'epoch': 4.0})

# %%
peft_name = "model/0929test"
trainer.model.save_pretrained(peft_name)
tokenizer.save_pretrained(peft_name)
# Out:
# ('model/0929test/tokenizer_config.json',
#  'model/0929test/special_tokens_map.json',
#  'model/0929test/tokenizer.model',
#  'model/0929test/added_tokens.json',
#  'model/0929test/tokenizer.json')

# %%
eval_model(raw_dataset[:50],pipe,"res/0929test/peft200.csv")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [05:56<00:00,  7.12s/it]
#                                               problem  \
# 0   You are a great scientist. Anser the following...
# 1   You are a great scientist. Anser the following...
# 2   You are a great scientist. Anser the following...
# 3   You are a great scientist. Anser the following...
# 4   You are a great scientist. Anser the following...
# 5   You are a great scientist. Anser the following...
# 6   You are a great scientist. Anser the following...
# 7   You are a great scientist. Anser the following...
# 8   You are a great scientist. Anser the following...
# 9   You are a great scientist. Anser the following...
# 10  You are a great scientist. Anser the following...
# 11  You are a great scientist. Anser the following...
# 12  You are a great scientist. Anser the following...
# 13  You are a great scientist. Anser the following...
# 14  You are a great scientist. Anser the following...
# 15  You are a great scientist. Anser the following...
# 16  You are a great scientist. Anser the following...
# 17  You are a great scientist. Anser the following...
# 18  You are a great scientist. Anser the following...
# 19  You are a great scientist. Anser the following...
# 20  You are a great scientist. Anser the following...
# 21  You are a great scientist. Anser the following...
# 22  You are a great scientist. Anser the following...
# 23  You are a great scientist. Anser the following...
# 24  You are a great scientist. Anser the following...
# 25  You are a great scientist. Anser the following...
# 26  You are a great scientist. Anser the following...
# 27  You are a great scientist. Anser the following...
# 28  You are a great scientist. Anser the following...
# 29  You are a great scientist. Anser the following...
# 30  You are a great scientist. Anser the following...
# 31  You are a great scientist. Anser the following...
# 32  You are a great scientist. Anser the following...
# 33  You are a great scientist. Anser the following...
# 34  You are a great scientist. Anser the following...
# 35  You are a great scientist. Anser the following...
# 36  You are a great scientist. Anser the following...
# 37  You are a great scientist. Anser the following...
# 38  You are a great scientist. Anser the following...
# 39  You are a great scientist. Anser the following...
# 40  You are a great scientist. Anser the following...
# 41  You are a great scientist. Anser the following...
# 42  You are a great scientist. Anser the following...
# 43  You are a great scientist. Anser the following...
# 44  You are a great scientist. Anser the following...
# 45  You are a great scientist. Anser the following...
# 46  You are a great scientist. Anser the following...
# 47  You are a great scientist. Anser the following...
# 48  You are a great scientist. Anser the following...
# 49  You are a great scientist. Anser the following...
#
#                                                answer  \
# 0                                                   3
# 1                                                   1
# 2                                                   1
# 3                                                   1
# 4   The key components of a LEID device structure ...
# 5                                                   1
# 6                                                   3
# 7                                                   1
# 8   A TRA transmitter is constructed from two terr...
# 9                                                   1
# 10                                                  1
# 11  A base pair is a pairing of two nucleotides (b...
# 12                                                  3
# 13  In recent years, machine learning techniques h...
# 14                                                  4
# 15                                                  3
# 16  Expressing the mutant kinesin in the mouse mod...
# 17                                                  1
# 18                                                  1
# 19                                                  2
# 20                                                  3
# 21                                                  2
# 22                                                  2
# 23                                                  2
# 24  Such a system would prevent the unrequired sex...
# 25                                                  1
# 26                                                  1
# 27                                                  3
# 28                                                  2
# 29                                                  2
# 30                                                  4
# 31                                                  4
# 32  A vertical cone substance is submerged in a na...
# 33                                                  2
# 34                                                  4
# 35  Dislocations in complex solids are much more c...
# 36                                                  1
# 37                                                  4
# 38                                                  1
# 39  The text states that water is more dense than ...
# 40                                                  2
# 41                                                  4
# 42                                                  2
# 43  Cellular growth is an example where standard m...
# 44                                                  1
# 45                                                  3
# 46  When internal components are fixed as rigid bu...
# 47                                                  4
# 48                                                  1
# 49  The increased intracellular levels of APOBEC3A...
#
#                                                  pred     score   type  \
# 0   3. A glucose biofuel cell (GBFC) consists of t...  1.000000  multi
# 1   1. LmrR has been shown to bind the compounds s...  1.000000  multi
# 2   1. In the clinical trial, disease progression ...  1.000000  multi
# 3   1. SmMIT-LAMP is a LAMP (Loop-mediated isother...  1.000000  multi
# 4    A LEID device structure typically consists of...  0.485981    gen
# 5   1. Point-contact spectroscopy and nuclear quad...  1.000000  multi
# 6   3. A QKD link requires both a quantum channel ...  1.000000  multi
# 7   1. The electromagnetic enhancement in SERS is ...  1.000000  multi
# 8    A TRA (Time-division duplex Radio) transmitte...  0.057143    gen
# 9   4. A synthetic dimension allows realization of...  0.000000  multi
# 10  1. Similar to 16S rRNA genes, tRNA gene sequen...  1.000000  multi
# 11   A base pair is a fundamental unit of nucleic ...  0.305085    gen
# 12  2. The operating mechanism was related to fiel...  0.000000  multi
# 13   Machine learning has been increasingly applie...  0.117647    gen
# 14  4. This likely refers to comparing the normal,...  1.000000  multi
# 15  3. This study aims to assess incidence trends ...  1.000000  multi
# 16   According to the passage, expressing the muta...  0.474576    gen
# 17  1. One limitation of ELISA is that it relies o...  1.000000  multi
# 18  4. Hugin neurons were good candidates for acti...  0.000000  multi
# 19  2. The microwave-assisted pyrolysis of Douglas...  1.000000  multi
# 20  2. Besides hydrophobic residues, the repeats f...  0.000000  multi
# 21  2. In resource theory, the thermal state is co...  1.000000  multi
# 22  2. An example of a prominent receptor that fol...  1.000000  multi
# 23  2. The dynamics are described by the creation ...  1.000000  multi
# 24   A system that constrains mutations to one sex...  0.180000    gen
# 25  1. Traditional thresholding methods can be ine...  1.000000  multi
# 26  4. X-ray CT produces 3D image stacks with comp...  0.000000  multi
# 27  3. Ideally, exploring SARS-CoV-2 proteins prov...  1.000000  multi
# 28  2) Using an entropy-based stabilization paradi...  1.000000  multi
# 29  2. In the IvyGAP dataset, different regions of...  1.000000  multi
# 30  4. The Ivy Glioblastoma Atlas Project (IvyGAP)...  1.000000  multi
# 31  2. In mice, mTOR signalling is required for OL...  0.000000  multi
# 32   The nanoparticles are submerged in the fluid....  0.054054    gen
# 33  2. Rational design of synthetic ΔR3/I5 analogu...  1.000000  multi
# 34  4. The high-level site-to-site lattice distort...  1.000000  multi
# 35   Dislocations in complex solids are different ...  0.422018    gen
# 36  2. Constructive quantum interference in the to...  0.000000  multi
# 37  4. The compromise can be addressed by introduc...  1.000000  multi
# 38  1. The text states that loss of Reelin, VLDLR,...  1.000000  multi
# 39   A hydrophilic/oleophobic coating may be more ...  0.044776    gen
# 40  2. No, the comb-shaped array has not yet been ...  1.000000  multi
# 41  2. Capping agents can selectively adsorb onto ...  0.000000  multi
# 42  2. The biological interactions.\nExplanation:\...  1.000000  multi
# 43   Cellular growth is an example of a process wh...  0.252427    gen
# 44  1. A disjoining potential or pressure in its g...  1.000000  multi
# 45  2. Computational tools with good predictive po...  0.000000  multi
# 46   When internal components are fixed as rigid b...  0.237624    gen
# 47  4. Ruoff and Rensing later proposed the antago...  1.000000  multi
# 48  2. A common feature to all these systems is th...  0.000000  multi
# 49   The APOBEC3A/B deletion has been linked to ca...  0.197531    gen
#
#     context
# 0     False
# 1      True
# 2      True
# 3     False
# 4      True
# 5      True
# 6     False
# 7      True
# 8     False
# 9      True
# 10    False
# 11     True
# 12    False
# 13    False
# 14     True
# 15    False
# 16     True
# 17    False
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25    False
# 26    False
# 27    False
# 28     True
# 29     True
# 30     True
# 31    False
# 32    False
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39    False
# 40     True
# 41     True
# 42     True
# 43     True
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49     True
